# %% [markdown]
# # OpenAlex Keyword Search – Ready for Google Colab
#
# **How to run (no local Python needed):**
# 1. Open in Google Colab.
# 2. Run **Runtime → Run all**. The first cell auto-installs required packages.
# 3. Results will be saved in `outputs/` (Colab: `/content/outputs`).
#
# Optionally set your email for polite OpenAlex API usage (see first cell: `OPENALEX_MAILTO`).

# %%
# --- Environment setup: auto-install dependencies & basic config ---
import os, sys, subprocess, pkgutil
from pathlib import Path

REQUIRED = ['matplotlib', 'openpyxl', 'pandas', 'requests', 'seaborn']

def ensure_packages(pkgs):
    missing = [p for p in pkgs if pkgutil.find_loader(p) is None]
    if missing:
        print("Installing missing packages:", ", ".join(missing))
        cmd = [sys.executable, "-m", "pip", "install", "-q"] + missing
        subprocess.check_call(cmd)
    else:
        print("All required packages already installed.")

ensure_packages(list(REQUIRED))

# Import after ensuring availability
import pandas as pd
import requests
import matplotlib.pyplot as plt
try:
    import seaborn as sns  # noqa: F401
except Exception:
    sns = None
import openpyxl  # noqa: F401

# --- Environment flags & paths ---
IN_COLAB = "google.colab" in sys.modules
ROOT = Path("/content") if IN_COLAB else Path.cwd()
OUTPUT_DIR = ROOT / "outputs"
OUTPUT_DIR.mkdir(parents=True, exist_ok=True)

# --- OpenAlex polite mailto ---
OPENALEX_MAILTO = os.environ.get("OPENALEX_MAILTO", "").strip()
if not OPENALEX_MAILTO:
    OPENALEX_MAILTO = "openalex-query@example.com"
    print("Note: Set OPENALEX_MAILTO for polite OpenAlex requests (using placeholder for now).")

def with_mailto(url: str) -> str:
    sep = "&" if "?" in url else "?"
    return f"{url}{sep}mailto={OPENALEX_MAILTO}"

print(f"Environment ready. Packages: {REQUIRED}")
print(f"Outputs → {OUTPUT_DIR}")
# Out:
# C:\Users\aengholm\AppData\Local\Temp\ipykernel_14048\3041374339.py:8: DeprecationWarning: 'pkgutil.find_loader' is deprecated and slated for removal in Python 3.14; use importlib.util.find_spec() instead
#   missing = [p for p in pkgs if pkgutil.find_loader(p) is None]
# All required packages already installed.
# Note: Set OPENALEX_MAILTO for polite OpenAlex requests (using placeholder for now).
# Environment ready. Packages: ['matplotlib', 'openpyxl', 'pandas', 'requests', 'seaborn']
# Outputs → C:\Users\aengholm\code_repos\cs_paper_bibliometrics\outputs

# %%
# Quick sanity check
import sys
print("Python:", sys.version.split()[0])
try:
    import pandas, requests, matplotlib
    print("pandas:", pandas.__version__)
    print("requests:", requests.__version__)
    print("matplotlib:", matplotlib.__version__)
    try:
        import seaborn
        print("seaborn:", seaborn.__version__)
    except Exception:
        print("seaborn: not installed")
    try:
        import openpyxl
        print("openpyxl:", openpyxl.__version__)
    except Exception:
        print("openpyxl: not installed")
except Exception as e:
    print("Import check error:", e)

print("OUTPUT_DIR:", str(OUTPUT_DIR))
# Out:
# Python: 3.12.9
# pandas: 2.2.3
# requests: 2.32.3
# matplotlib: 3.10.0
# seaborn: 0.13.2
# openpyxl: 3.1.5
# OUTPUT_DIR: C:\Users\aengholm\code_repos\cs_paper_bibliometrics\outputs

# %%
# Package imports and installs
import importlib
import subprocess
import sys

required_packages = {
    "matplotlib": "matplotlib",
    "seaborn": "seaborn",
    "pandas": "pandas",
    "requests": "requests",
    "openpyxl":"openpyxl"
}

for pkg_name, import_name in required_packages.items():
    if importlib.util.find_spec(import_name) is None:
        print(f"📦 Installing {pkg_name}...")
        subprocess.check_call([sys.executable, "-m", "pip", "install", pkg_name])
    else:
        print(f"✅ {pkg_name} already installed.")

# Now import all the packages
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import requests
import time
# Out:
# ✅ matplotlib already installed.
# ✅ seaborn already installed.
# ✅ pandas already installed.
# ✅ requests already installed.
# ✅ openpyxl already installed.

# %%
### USER INPUT ###
# Choose: "default" or "title_and_abstract". "default" covers title, abstract as well as fulltext (when indexed in openalex)
# --- Search / filter config (shared by all calls) ---
SEARCH_SCOPE = "default"   # or "title_and_abstract"
FROM_YEAR    = 2000
TO_YEAR      = None        # e.g., 2025, or leave as None
JOURNAL_ONLY = False       # True -> restrict to journal articles
EMAIL        = "you@uni.se"


# List of keywords
keywords = [
    "systems engineering",
    "system dynamics",
    "engineering systems",
    "engineering design",
    "systemic design",
    "soft systems methodology",
    "systems thinking",
    "complex adaptive systems",
    "transition",
    "strategic niche management",
    "strategic transition management",
    "exploratory modeling",
    "life-cycle optimization",
    "operations research",
    "transport policy analysis"
]
# Shorter version override for debugging
keywords = [
    "systems engineering",
    "system dynamics",
    "engineering design",
]

# %%
### Functions to support the API calls and data processing ###

# Base API endpoint for group_by queries
BASE_URL = "https://api.openalex.org/works"
from typing import Literal
import requests

BASE_URL = "https://api.openalex.org/works"

def _search_field(scope: Literal["default", "title_and_abstract"]) -> str:
    return "default.search" if scope == "default" else "title_and_abstract.search"

def build_openalex_filter(
    keyword: str,
    journal_only: bool = True,
    from_year: int | None = None,
    to_year: int | None = None,
    search_scope: Literal["default", "title_and_abstract"] = "default",
) -> str:
    field = _search_field(search_scope)
    parts = [
        f'{field}:"{keyword}"',
        f'{field}:"transport system"|"transportation system"',
        f'{field}:"transformation"|"transition"',
    ]
    if journal_only:
        parts.append("type:journal-article")
    if from_year:
        parts.append(f"from_publication_date:{from_year}-01-01")
    if to_year:
        parts.append(f"to_publication_date:{to_year}-12-31")
    return ",".join(parts)

def fetch_publication_counts(
    keyword: str,
    journal_only: bool = True,
    email: str = "you@uni.se",
    from_year: int | None = None,
    to_year: int | None = None,
    search_scope: Literal["default", "title_and_abstract"] = "default",
) -> dict[str, int]:
    params = {
        "group_by": "publication_year",
        "filter": build_openalex_filter(
            keyword,
            journal_only=journal_only,
            from_year=from_year,
            to_year=to_year,
            search_scope=search_scope,
        ),
        "per_page": 200,
        "mailto": email,
    }
    r = requests.get(BASE_URL, params=params, timeout=60)
    r.raise_for_status()
    data = r.json()
    counts: dict[str, int] = {}
    for item in data.get("group_by", []):
        try:
            counts[str(item["key"])] = int(item["count"])
        except Exception:
            pass
    return counts

def _reconstruct_abstract(abstract_inv_idx: dict | None) -> str | None:
    """Turn OpenAlex abstract_inverted_index into plain text."""
    if not abstract_inv_idx:
        return None
    # gather (pos, word) then place them into an array
    items = [(pos, word) for word, poses in abstract_inv_idx.items() for pos in poses]
    if not items:
        return None
    items.sort(key=lambda x: x[0])
    max_pos = items[-1][0]
    words = [""] * (max_pos + 1)
    for pos, word in items:
        words[pos] = word
    return " ".join(words).strip()

def _flatten_work(w: dict, matched_keyword: str, include_abstract: bool = False) -> dict:
    primary_loc = (w.get("primary_location") or {})
    src = (primary_loc.get("source") or {})
    oa = (w.get("open_access") or {})
    authorships = w.get("authorships") or []

    authors = []
    for a in authorships:
        author = (a.get("author") or {})
        name = author.get("display_name") or a.get("raw_author_name")
        if name:
            authors.append(name)

    doi = w.get("doi")
    doi_url = None
    if doi:
        # normalize to https://doi.org/...
        tail = doi.split("doi.org/")[-1]
        doi_url = f"https://doi.org/{tail}"

    openalex_url = w.get("id")
    openalex_id = (openalex_url or "").split("/")[-1] if openalex_url else None

    abstract_txt = None
    if include_abstract:
        abstract_txt = _reconstruct_abstract(w.get("abstract_inverted_index"))

    return {
        "matched_keyword": matched_keyword,
        "title": w.get("display_name"),
        "publication_year": w.get("publication_year"),
        "type": w.get("type"),
        "language": w.get("language"),
        "journal": src.get("display_name"),
        "publisher": src.get("publisher"),
        "is_oa": oa.get("is_oa"),
        "oa_status": oa.get("oa_status"),
        "oa_url": oa.get("oa_url") or primary_loc.get("landing_page_url"),
        "cited_by_count": w.get("cited_by_count"),
        "biblio": w.get("biblio"),  # volume/issue/pages (dict)
        "concepts_count": len(w.get("concepts") or []),
        "authors": "; ".join(authors),
        "doi": doi,
        "doi_url": doi_url,
        "openalex_id": openalex_id,
        "openalex_url": openalex_url,
        "abstract": abstract_txt,
    }

def fetch_works_metadata(
    keyword: str,
    limit: int = 500,                       # how many works per keyword
    journal_only: bool = True,
    from_year: int | None = None,
    to_year: int | None = None,
    search_scope: Literal["default", "title_and_abstract"] = "default",
    email: str = "you@uni.se",
    include_abstract: bool = False,
    polite_sleep: float = 0.2,              # be nice to the API
) -> list[dict]:
    """Fetch paginated Works (metadata) for one keyword."""
    filt = build_openalex_filter(
        keyword, journal_only=journal_only,
        from_year=from_year, to_year=to_year,
        search_scope=search_scope,
    )

    select_fields = ",".join([
        "id","doi","display_name","publication_year","type","language",
        "authorships","primary_location","open_access","cited_by_count",
        "biblio","concepts"  # avoid referenced_works to keep payload small
    ])
    if include_abstract:
        select_fields += ",abstract_inverted_index"

    rows = []
    cursor = "*"
    fetched = 0

    while fetched < limit:
        per_page = min(200, limit - fetched)
        params = {
            "filter": filt,
            "per_page": per_page,
            "cursor": cursor,
            "select": select_fields,
            "mailto": email,
            "sort": "publication_year:desc",
        }
        r = requests.get(BASE_URL, params=params, timeout=60)
        r.raise_for_status()
        data = r.json()
        works = data.get("results", []) or []
        cursor = (data.get("meta") or {}).get("next_cursor")
        if not works:
            break

        for w in works:
            rows.append(_flatten_work(w, matched_keyword=keyword, include_abstract=include_abstract))
        fetched += len(works)

        if not cursor:
            break
        time.sleep(polite_sleep)

    return rows

def collect_metadata_for_keywords(
    keywords: list[str],
    limit_per_kw: int = 500,
    journal_only: bool = True,
    from_year: int | None = None,
    to_year: int | None = None,
    search_scope: Literal["default","title_and_abstract"] = "default",
    include_abstract: bool = False,
    email: str = "you@uni.se",
) -> pd.DataFrame:
    """Loop over keywords, fetch works, de-duplicate, and aggregate matched keywords."""
    all_rows = []
    for kw in keywords:
        print(f"Collecting metadata for: {kw}")
        rows = fetch_works_metadata(
            kw, limit=limit_per_kw, journal_only=journal_only,
            from_year=from_year, to_year=to_year,
            search_scope=search_scope, include_abstract=include_abstract, email=email
        )
        all_rows.extend(rows)

    df = pd.DataFrame(all_rows)
    if df.empty:
        return df

    # If a work matched multiple keywords: keep one row and aggregate the matches
    agg = (df.groupby("openalex_id", dropna=False)
             .agg({
                 "openalex_url":"first",
                 "title":"first",
                 "publication_year":"first",
                 "type":"first",
                 "language":"first",
                 "journal":"first",
                 "publisher":"first",
                 "is_oa":"first",
                 "oa_status":"first",
                 "oa_url":"first",
                 "cited_by_count":"first",
                 "biblio":"first",
                 "concepts_count":"first",
                 "authors":"first",
                 "doi":"first",
                 "doi_url":"first",
                 "abstract":"first",
                 "matched_keyword": lambda s: "; ".join(sorted(set(x for x in s if pd.notna(x)))),
             })
             .reset_index())
    # Put aggregated keywords into a friendlier column name
    agg = agg.rename(columns={"matched_keyword": "matched_keywords"})
    return agg

# %%
# Collect all results
import urllib.parse as _u, time
# First search the number of publications

all_counts = {}
for kw in keywords:
    filt = build_openalex_filter(
        kw, journal_only=JOURNAL_ONLY, from_year=FROM_YEAR, search_scope=SEARCH_SCOPE
    )
    url = f"{BASE_URL}?{_u.urlencode({'group_by':'publication_year','filter':filt,'per_page':200,'mailto':EMAIL})}"
    print(f"Processing (counts): {kw}\n  scope={SEARCH_SCOPE}\n  filter={filt}\n  url={url}")
    all_counts[kw] = fetch_publication_counts(
        kw, journal_only=JOURNAL_ONLY, email=EMAIL, from_year=FROM_YEAR, search_scope=SEARCH_SCOPE
    )
    time.sleep(0.5)

# Turn counts into a DataFrame (years x keyword)
import pandas as pd
counts_df = (pd.DataFrame(all_counts)
               .rename_axis("publication_year")
               .reset_index()
               .sort_values("publication_year"))
print(counts_df.head())

# --- 2) metadata for manual screening (richer, paginated) ---
metadata_df = collect_metadata_for_keywords(
    keywords,
    limit_per_kw=2000,           # raise if you want more; set high to fetch “all”
    journal_only=JOURNAL_ONLY,
    from_year=FROM_YEAR,
    search_scope=SEARCH_SCOPE,
    include_abstract=False,      # True if you want reconstructed abstracts
    email=EMAIL,
)
print(f"Total unique works (metadata): {len(metadata_df)}")
display(metadata_df.head(10))
# Out:
# Processing (counts): systems engineering
#   scope=default
#   filter=default.search:"systems engineering",default.search:"transport system"|"transportation system",default.search:"transformation"|"transition",from_publication_date:2000-01-01
#   url=https://api.openalex.org/works?group_by=publication_year&filter=default.search%3A%22systems+engineering%22%2Cdefault.search%3A%22transport+system%22%7C%22transportation+system%22%2Cdefault.search%3A%22transformation%22%7C%22transition%22%2Cfrom_publication_date%3A2000-01-01&per_page=200&mailto=you%40uni.se
# Processing (counts): system dynamics
#   scope=default
#   filter=default.search:"system dynamics",default.search:"transport system"|"transportation system",default.search:"transformation"|"transition",from_publication_date:2000-01-01
# ...

# %%
# --- export metadata for screening ---
#metadata_df.to_csv(OUTPUT_DIR / "openalex_screening_results.csv", index=False)
metadata_df.to_excel(OUTPUT_DIR / "openalex_screening_results.xlsx", index=False)

# %%
# Convert to long-format (to facilitate plotting) and filter by year
records = []
for keyword, yearly_counts in all_counts.items():
    for year, count in yearly_counts.items():
        try:
            year_int = int(year)
            records.append({"Keyword": keyword, "Year": year_int, "Count": int(count)})
        except Exception:
            continue

# If no records, create an empty DataFrame with expected columns to avoid KeyError
if records:
    df_long = pd.DataFrame(records)
else:
    df_long = pd.DataFrame(columns=["Keyword", "Year", "Count"])

base_year = FROM_YEAR or 2000 
# Only filter if the Year column exists and has data
if not df_long.empty and "Year" in df_long.columns:
    df_long = df_long[(df_long["Year"] > base_year - 1) & (df_long["Year"] < 2025)]
else:
    print("No data returned from OpenAlex for the provided keywords.")

# %%
# Plot with seaborn
plt.figure(figsize=(14, 8))
sns.lineplot(data=df_long, x="Year", y="Count", hue="Keyword", style="Keyword")
sns.despine()
plt.title("Publication Trends in OpenAlex by Keyword (Journal Articles Only)")
plt.xlabel("Year")
plt.ylabel("Number of Publications")
plt.grid(True)
plt.tight_layout()

plt.show()

# %%
# Calculate relative growth rates indexed to the first year used in the plot

if not df_long.empty:
    base_counts = df_long[df_long['Year'] == base_year].set_index('Keyword')['Count']
    if not base_counts.empty:
        df_long['RelativeGrowth'] = df_long.apply(
            lambda r: (r['Count'] / base_counts.get(r['Keyword'], float('nan')))
            if base_counts.get(r['Keyword'], float('nan')) not in (0, float('nan')) else float('nan'),
            axis=1,
        )
    else:
        df_long['RelativeGrowth'] = float('nan')

# Plot the relative growth over time
if not df_long.empty:
    plt.figure(figsize=(14, 8))
    sns.lineplot(data=df_long, x='Year', y='RelativeGrowth', hue='Keyword', style='Keyword')
    sns.despine()
    plt.title(f'Relative Growth Indexed to {base_year}')
    plt.xlabel('Year')
    plt.ylabel('Relative Growth (Base Year = 1)')
    plt.ylim(1,)
    plt.grid(True)
    plt.tight_layout()
    plt.show()
else:
    print("Skipping relative growth plot due to no data.")

# %%
# Show and export
df_long.to_csv(OUTPUT_DIR / "openalex_keyword_trends_by_year.csv", index=False)
df_long.tail()

# %%
# Out:
#                Keyword  Year  Count  RelativeGrowth
# 72  engineering design  2006     38        1.461538
# 73  engineering design  2007     38        1.461538
# 74  engineering design  2000     26        1.000000
# 75  engineering design  2001     26        1.000000
# 76  engineering design  2004     26        1.000000
